# %% [markdown]
# # Naive Bayes Algorithm

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic=titanic.drop(['sibsp','parch','embarked','class','who','adult_male','deck','embark_town','alive','alone'],axis=1)
titanic
# Out:
#      survived  pclass     sex   age     fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# fare          0
# dtype: int64

# %%
titanic=titanic.dropna()
titanic
# Out:
#      survived  pclass     sex   age     fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 885         0       3  female  39.0  29.1250
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [714 rows x 5 columns]

# %%
titanic['sex']=titanic['sex'].astype("category")
titanic['sex']=titanic['sex'].cat.codes
# Out:
# C:\Users\aditya\AppData\Local\Temp\ipykernel_11384\3161564843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['sex']=titanic['sex'].astype("category")
# C:\Users\aditya\AppData\Local\Temp\ipykernel_11384\3161564843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['sex']=titanic['sex'].cat.codes

# %%
titanic
# Out:
#      survived  pclass  sex   age     fare
# 0           0       3    1  22.0   7.2500
# 1           1       1    0  38.0  71.2833
# 2           1       3    0  26.0   7.9250
# 3           1       1    0  35.0  53.1000
# 4           0       3    1  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 885         0       3    0  39.0  29.1250
# 886         0       2    1  27.0  13.0000
# 887         1       1    0  19.0  30.0000
# 889         1       1    1  26.0  30.0000
# 890         0       3    1  32.0   7.7500
#
# [714 rows x 5 columns]

# %%
x=titanic.drop(columns='survived')
y=titanic['survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)

# %%
len(x_train)
# Out:
# 571

# %%
len(x_test)
# Out:
# 143

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(x_train,y_train)
# Out:
# 0.7740805604203153

# %%
x_test[:10]
# Out:
#      pclass  sex   age      fare
# 689       1    0  15.0  211.3375
# 278       3    1   7.0   29.1250
# 506       2    0  33.0   26.0000
# 9         2    0  14.0   30.0708
# 494       3    1  21.0    8.0500
# 149       2    1  42.0   13.0000
# 473       2    0  23.0   13.7917
# 467       1    1  56.0   26.5500
# 795       2    1  39.0   13.0000
# 864       2    1  24.0   13.0000

# %%
model.predict(x_test[:10])
# Out:
# array([1, 0, 1, 1, 0, 0, 1, 0, 0, 0], dtype=int64)

# %%
y_test[:10]
# Out:
# 689    1
# 278    0
# 506    1
# 9      1
# 494    0
# 149    0
# 473    1
# 467    0
# 795    0
# 864    0
# Name: survived, dtype: int64
