# %%
from secret_key import openAI_api_key

import os
os.environ["OPENAI_API_KEY"]=openAI_api_key

from langchain_openai import OpenAI


from langchain.chains import ConversationChain

convo=ConversationChain(
    llm=OpenAI(temperature=0.6)
)
print(convo.prompt.template)
# Out:
# The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.
#
# Current conversation:
# {history}
# Human: {input}
# AI:
# C:\Users\my lapi\AppData\Local\Temp\ipykernel_7880\1196797490.py:11: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use RunnableWithMessageHistory: https://python.langchain.com/v0.2/api_reference/core/runnables/langchain_core.runnables.history.RunnableWithMessageHistory.html instead.
#   convo=ConversationChain(

# %%
convo.run("who won the 2011 cricket world cup?")
# Out:
# C:\Users\my lapi\AppData\Local\Temp\ipykernel_7880\3442085142.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   convo.run("who won the 2011 cricket world cup?")
# " The 2011 Cricket World Cup was won by India. They defeated Sri Lanka by six wickets in the final match, which took place at the Wankhede Stadium in Mumbai, India. This was India's second time winning the World Cup, the first being in 1983. The tournament was hosted by India, Sri Lanka, and Bangladesh, and featured 14 teams. It was a very exciting and competitive event, with many memorable moments and performances."

# %%
convo.run("what is the national vegetable of india?")
# Out:
# ' The national vegetable of India is the pumpkin. It is also known as kaddu or bhopla in Hindi and is widely used in Indian cuisine. It is a versatile vegetable that can be used in curries, soups, and even desserts. Other popular vegetables in India include eggplant, cauliflower, and okra.'

# %%
convo.run("who was the captain of the loosing team?")
# Out:
# " The captain of the losing team in the 2011 Cricket World Cup final was Kumar Sangakkara from Sri Lanka. He is a highly respected and accomplished cricketer, known for his elegant batting style and strong leadership skills. Despite the loss in the final, Sangakkara's team put up a brave fight and gave a tough competition to the Indian team."
