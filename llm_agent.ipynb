# %%
from secret_key import openAI_api_key

import os
os.environ["OPENAI_API_KEY"]=openAI_api_key

from langchain_openai import OpenAI

llm=OpenAI(temperature=0.6)

from langchain.agents import AgentType, initialize_agent, load_tools
from langchain.llms import OpenAI

tools=load_tools(["wikipedia","llm-math"],llm=llm)
# pip install wikipedia
# pip install numexpr for llm-math
agent=initialize_agent(
    tools,
    llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION
)
agent.run("when was sachin tendulkar born ? what will be his age in 2025?")
# Out:
# C:\Users\my lapi\AppData\Local\Temp\ipykernel_5956\116309787.py:16: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 1.0. Use Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc. instead.
#   agent=initialize_agent(
# C:\Users\my lapi\AppData\Local\Temp\ipykernel_5956\116309787.py:21: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   agent.run("when was sachin tendulkar born ? what will be his age in 2025?")
# 'Sachin Tendulkar will be 52 years old in 2025.'

# %%
# generate api key from google serpapi and save it in any file
# pip install google-search-results
from secretserp_key import serpapi_key
os.environ["SERPAPI_API_KEY"]=serpapi_key

tools=load_tools(["serpapi","llm-math"],llm=llm)

agent=initialize_agent(
    tools,
    llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION
)
agent.run("what was the population of india in 2021")
# Out:
# 'The population of India in 2021 is 1.408 billion.'
