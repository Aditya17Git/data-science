# %%
import re

# %%
chat1='aditya:Hey why i am getting errors in submitting the form # 15?'
chat2='aditya:How much time does it takes to resolve the issue?'
chat3='aditya:email the reasons and the solution to xyz17@abc.com or text me on my mobile number 9323454321, (91)-987-676-7321'

# %%
# matching numbers

# %%
pattern="\d{10}"
matches=re.findall(pattern,chat3)
matches
# Out:
# ['9323454321']

# %%
# matching phone numbers of different formats

# %%
pattern="\d{10}|\(\d{2}\)-\d{3}-\d{3}-\d{4}"
matches=re.findall(pattern,chat3)
matches
# Out:
# ['9323454321', '(91)-987-676-7321']

# %%
# matching email

# %%
pattern="[a-z0-9]*@[a-z]*\.com"
matches=re.findall(pattern,chat3)
matches
# Out:
# ['xyz17@abc.com']

# %%
# matching form no. with special symbol like... '#'

# %%
pattern="form[^\d]*\d*"
matches=re.findall(pattern,chat1)
matches
# Out:
# ['form # 15']

# %%
# matching only the form number

# %%
pattern="form[^\d]*(\d*)"
matches=re.findall(pattern,chat1)
matches
# Out:
# ['15']

# %%
# retrieving any personal information of any personality

# %%
text='''
Born	Mukesh Dhirubhai Ambani
19 April 1957 (age 67)
Aden, Colony of Aden
(present-day Yemen)[1][2]
Nationality	Indian
Alma mater	
St. Xavier's College, Mumbai
Institute of Chemical Technology (B.E.)
Occupation(s)	Chairman and MD, Reliance Industries
Spouse	Nita Ambani ​(m. 1985)​[3]
Children	3, including Akash'''
# the above information has been taken from wikipedia

# %%
pattern="age (\d+)"
matches=re.findall(pattern,text)
matches
# Out:
# ['67']

# %%
pattern="Born(.*)"
matches=re.findall(pattern,text)
matches[0].strip()
# strip in python is used to remove the white spaces
# Out:
# 'Mukesh Dhirubhai Ambani'

# %%
pattern="Born.*\n(.*)\(age"
matches=re.findall(pattern,text)
matches[0].strip()
# Out:
# '19 April 1957'

# %%
pattern="\(age.*\n(.*)"
matches=re.findall(pattern,text)
matches[0].strip()
# Out:
# 'Aden, Colony of Aden'

# %%
# finding information by defining a function

# %%
def get_pattern_match(pattern,text):
    matches=re.findall(pattern,text)
    if matches:
        return matches[0]

# %%
get_pattern_match("\(age.*\n(.*)",text)
# Out:
# 'Aden, Colony of Aden'

# %%
def get_personal_info(text):
    age=get_pattern_match("age (\d+)",text)
    full_name=get_pattern_match("Born(.*)",text)
    birth_date=get_pattern_match("Born.*\n(.*)\(age",text)
    birth_place=get_pattern_match("\(age.*\n(.*)",text)

    return {
        "age":int(age),
        "name":full_name.strip(),
        "date of birth":birth_date,
        "place of birth":birth_place
    }

# %%
get_personal_info(text)
# Out:
# {'age': 67,
#  'name': 'Mukesh Dhirubhai Ambani',
#  'date of birth': '19 April 1957 ',
#  'place of birth': 'Aden, Colony of Aden'}
